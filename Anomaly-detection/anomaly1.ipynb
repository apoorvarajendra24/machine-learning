# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("creditcard.csv")
df
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
X = df.drop('Class',axis=1)
y = df['Class']
X
# Out:
#             Time         V1         V2  ...       V27       V28  Amount
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053  149.62
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    2.69
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752  378.66
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458  123.50
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153   69.99
# ...          ...        ...        ...  ...       ...       ...     ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    0.77
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527   24.79
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561   67.88
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533   10.00
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649  217.00
#
# [284807 rows x 30 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().set_output(transform='pandas')

# %%
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
#             Time        V1        V2  ...       V27       V28    Amount
# 0      -1.996583 -0.694242 -0.044075  ...  0.330892 -0.063781  0.244964
# 1      -1.996583  0.608496  0.161176  ... -0.022256  0.044608 -0.342475
# 2      -1.996562 -0.693500 -0.811578  ... -0.137137 -0.181021  1.160686
# 3      -1.996562 -0.493325 -0.112169  ...  0.155396  0.186189  0.140534
# 4      -1.996541 -0.591330  0.531541  ...  0.543620  0.651816 -0.073403
# ...          ...       ...       ...  ...       ...       ...       ...
# 284802  1.641931 -6.065842  6.099286  ...  2.337901  2.495529 -0.350151
# 284803  1.641952 -0.374121 -0.033356  ...  0.169641 -0.162164 -0.254117
# 284804  1.641974  0.980024 -0.182434  ...  0.011037 -0.080467 -0.081839
# 284805  1.641974 -0.122755  0.321250  ...  0.269604  0.316687 -0.313249
# 284806  1.642058 -0.272331 -0.114899  ... -0.005984  0.041350  0.514355
#
# [284807 rows x 30 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2,random_state=42)
X_pca = pca.fit_transform(X_scaled)
X_pca
# Out:
# array([[ 0.41663045, -2.53266428],
#        [-0.39345348, -2.0773255 ],
#        [ 1.86852545, -2.53349699],
#        ...,
#        [-0.19406338,  2.07078798],
#        [-0.46608925,  1.22539363],
#        [ 0.76759651,  1.90590292]], shape=(284807, 2))

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[y==0, 0], X_pca[y==0, 1], s=2, c='blue', label='Normal')
plt.scatter(X_pca[y==1, 0], X_pca[y==1, 1], s=10, c='red', label='Fraud (Anomaly)')
plt.title("Credit Card Fraud Detection Dataset (2D PCA Projection)")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import IsolationForest
iso = IsolationForest(contamination=0.002,random_state=42)
iso.fit(X_pca)
predict = iso.predict(X_pca)
predict
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(284807,))

# %%
import numpy as np
index = np.where(predict==-1)[0]
index
# Out:
# array([   164,   1632,   4727,   6783,   7243,   7469,   7485,   7600,
#          7617,  11222,  12878,  15714,  15835,  17454,  18570,  18653,
#         19386,  19760,  21586,  22112,  22636,  23128,  23852,  23931,
#         24616,  24633,  25682,  26432,  29279,  29293,  29667,  30589,
#         31686,  32145,  32932,  33756,  33949,  36029,  36154,  36889,
#         37000,  37704,  37727,  39999,  40695,  43823,  44513,  44562,
#         44947,  46298,  46841,  47102,  47299,  48165,  48529,  48741,
#         48955,  49406,  50569,  50922,  53953,  54018,  54696,  55829,
#         56335,  57209,  58465,  58962,  59807,  61333,  62164,  62413,
#         62508,  62868,  62946,  63201,  63645,  63989,  64780,  67428,
#         67724,  67744,  68120,  68245,  68942,  69164,  69372,  69843,
#         72407,  73134,  74243,  74699,  76679,  77394,  77963,  80111,
#         82331,  84352,  85984,  88328,  88496,  88621,  88805,  89534,
# ...

# %%
plt.scatter(X_pca[:,0], X_pca[:,1], s=2, c='blue', label='Normal')
plt.scatter(X_pca[index,0],X_pca[index,1], s=3, c='red', label='Anomaly')
plt.grid(True)
plt.legend()

# %%
print(f"Number of anomalies detected: {len(index)}")
print(f"Percentage of anomalies: {len(index) / len(X_pca) * 100:.4f}%")
# Out:
# Number of anomalies detected: 569
# Percentage of anomalies: 0.1998%
